# %%
import numpy as np
import pandas as pd
from pandas import read_csv
print('ok')
# Out:
# ok

# %%
data = pd.read_csv("200802.txt")

# %%
data = data.drop(columns=['Year',  'TaxiIn', 'TaxiOut', 'CarrierDelay', 'WeatherDelay', 'NASDelay','SecurityDelay','LateAircraftDelay'])

# %%
# 1. Какая из причин отмены рейса (`CancellationCode`) была самой частой? (расшифровки кодов можно найти в описании данных)

# %%
print(data.groupby('CancellationCode').size())
# Out:
# CancellationCode
# A    54330
# B    54904
# C    28188
# D       12
# dtype: int64

# %%
# A = carrier, B = weather, C = NAS, D = security
# Больше всего причина B

# %%
# 2. Найдите среднее, минимальное и максимальное расстояние, пройденное самолетом.

# %%
print(data.groupby('TailNum').Distance.agg(['mean', 'min', 'max']))
# Out:
#                 mean  min   max
# TailNum
# 80009E    448.082397   56  1139
# 80019E    444.955875   56  1048
# 80059E    477.571120   56  1139
# 80129E    441.490909   56  1139
# 80139E    448.020690   56  1139
# 80199E    462.456710   56  1395
# 80209E    471.293924   56  1139
# 80219E    475.417391   56  1139
# 80239E    478.893715   56  1139
# 80249E    485.736562   56  1194
# 80259E    458.866857   56  1139
# 80269E    475.152449   56  1139
# 80279E    479.739060   56  1139
# 80299E    484.782011   74  1139
# 80309E    431.741153   56  1395
# 80319E    406.861945   56  1087
# 80329E    471.671676   76  1139
# 80339E    458.596958   76  1045
# 80349E    444.193966   56  1139
# 80359E    444.413572   56  1085
# 80369E    462.295355   56  1139
# 80399E    444.606320   56  1139
# 80409E    467.827303   56  1085
# 80419E    434.133018   56  1139
# 83909E    440.979534   56  1139
# 84099E    421.327352   56  1139
# 84129E    421.650291   56  1045
# 84169E    424.562734   56  1139
# ...

# %%
# 3. Не выглядит ли подозрительным минимальное пройденное расстояние? В какие дни и на каких рейсах оно было? Какое расстояние было пройдено этими же рейсами в другие дни?

# %%
data[data['Distance'] == data['Distance'].min()]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2547298      5          15          4   2037.0        1800   2125.0
# 4392215      8          10          7   1315.0        1220   1415.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum   ...     CRSElapsedTime  \
# 2547298        1900            OH       4988  N806CA   ...               60.0
# 4392215        1320            OH       5572  N819CA   ...               60.0
#
#          AirTime  ArrDelay  DepDelay  Origin Dest Distance  Cancelled  \
# 2547298     31.0     145.0     157.0     JFK  LGA       11          0
# 4392215     14.0      55.0      55.0     JFK  LGA       11          0
#
#          CancellationCode Diverted
# 2547298               NaN        0
# 4392215               NaN        0
#
# [2 rows x 21 columns]

# %%
print(data[data["FlightNum"] == 4988]['Distance'])
# Out:
# 151771     834
# 152430     834
# 153088     834
# 153545     834
# 154096     834
# 154750     834
# 155308     834
# 155962     834
# 156627     834
# 157287     834
# 157747     834
# 158301     834
# 158958     834
# 159514     834
# 160169     834
# 160833     834
# 161492     834
# 161950     834
# 162493     834
# 163151     834
# 163707     834
# 164361     834
# 165027     834
# 165688     834
# 166150     834
# 166704     834
# 167361     834
# 167917     834
# 168567     834
# 453560     834
#           ...
# 6776729    903
# 6776730    903
# 6776731    903
# 6776732    903
# 6776733    903
# 6776734    903
# 6776735    903
# 6776736    903
# 6776737    903
# 6776738    903
# 6776739    903
# 6776740    903
# 6776741    903
# 6776742    903
# 6776743    903
# 6776744    903
# 6776745    903
# 6776746    903
# 6776747    903
# 6776748    903
# 6776749    903
# 6776750    903
# 6776751    903
# 6776752    903
# 6776753    903
# 6776754    903
# 6776755    903
# ...

# %%
print(data[data["FlightNum"] == 5572]['Distance'])
# Out:
# 151629     544
# 152291     544
# 152949     544
# 153419     544
# 153963     544
# 154611     544
# 155185     544
# 155823     544
# 156485     544
# 157148     544
# 157622     544
# 158169     544
# 158819     544
# 159392     544
# 160029     544
# 160692     544
# 161355     544
# 161828     544
# 162361     544
# 163012     544
# 163585     544
# 164222     544
# 164885     544
# 165549     544
# 166024     544
# 166572     544
# 167222     544
# 167795     544
# 168432     544
# 169083     544
#           ...
# 6635221    329
# 6635222    329
# 6635223    329
# 6635224    329
# 6635225    329
# 6635226    329
# 6635227    329
# 6635228    329
# 6635229    329
# 6635230    329
# 6635231    329
# 6635232    329
# 6771546    669
# 6771547    134
# 6771548    134
# 6771549    134
# 6771550    134
# 6771551    134
# 6771552    134
# 6771553    134
# 6771554    134
# 6771555    134
# 6771556    134
# 6771557    134
# 6771558    134
# 6771559    669
# 6771560    508
# ...

# %%
# 4. Из какого аэропорта было произведено больше всего вылетов? В каком городе он находится?

# %%
print(data.groupby('Origin').size().nlargest(1).reset_index(name='counts'))
# Out:
#   Origin  counts
# 0    ATL  414513

# %%
# 5. Найдите для каждого аэропорта среднее время полета (`AirTime`) по всем вылетевшим из него рейсам. Какой аэропорт имеет наибольшее значение этого показателя?

# %%
print(data.groupby('Origin').AirTime.mean().nlargest(1))
# Out:
# Origin
# SJU    203.850843
# Name: AirTime, dtype: float64

# %%
# 6. Найдите аэропорт, у которого наибольшая доля задержанных (`DepDelay > 0`) рейсов. Исключите при этом из рассмотрения аэропорты, из которых было отправлено меньше 1000 рейсов (используйте функцию `filter` после `groupby`).

# %%
groupped = data.groupby('Origin').count()
# print(groupped['DepDelay'])
# print(groupped)
# print(groupped['DepDelay'])

groupped = data.groupby('Origin')
groupped = groupped.filter(groupper['Origi']size() > 1000)

# %%
print(groupped[groupped['DepDelay'] > 1000])
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# Origin
# ABE       4807        4807       4807     4663        4807     4645
# ABI       2660        2660       2660     2617        2660     2616
# ABQ      41146       41146      41146    40817       41146    40745
# ABY       1095        1095       1095     1078        1095     1078
# ACT       1993        1993       1993     1919        1993     1919
# ACV       3714        3714       3714     3587        3714     3571
# AEX       2330        2330       2330     2256        2330     2251
# AGS       2403        2403       2403     2359        2403     2358
# ALB      13474       13474      13474    13212       13474    13175
# AMA       7496        7496       7496     7369        7496     7355
# ANC      19327       19327      19327    19069       19327    18973
# ASE       5307        5307       5307     4823        5307     4817
# ATL     414513      414513     414513   408735      414513   407877
# ...

# %%
# groupped = data.groupby('Origin').size().reset_index(name='counts')
# groupped = data.groupby('Origin').count()
# droupped = groupped[['Origin','DepDelay']]
# print(groupped)
# data[data['Distance'] == data['Distance'].min()]
# groupped[groupped['counts'] > 1000]['DepDelay']

# %%
groupped = groupped[groupped['DepDelay'] > 1000]
print(groupped['DepDelay'].nlargest(1))
# Out:
# Origin
# ATL    408735
# Name: DepDelay, dtype: int64

# %%
DFGB = data.groupby('Origin')['DepDelay']
DFGB_Filtered = data[data.DepDelay > 0].groupby('Origin')['DepDelay']
(DFGB_Filtered.count() / data.count() * (data.count() >= 1000)).argmax()
